# %%
import pandas as pd

# Example patient data (replace with model-predicted values)
sample_patient = {
    'Age': 52,
    'Medical Condition': 'Hypertension',
    'Medication': 'Aspirin',
    'Predicted_Test_Result': 1
}

def generate_ai_doctor_recommendation(patient):
    age = patient['Age']
    condition = patient['Medical Condition']
    medication = patient['Medication']
    result = patient['Predicted_Test_Result']

    # Interpretation of predicted result
    if result == 0:
        result_text = "normal and within safe limits"
        advice = (
            "Continue maintaining your current medication routine, stay hydrated, "
            "and schedule regular checkups to monitor your condition."
        )
    elif result == 1:
        result_text = "slightly elevated and requires attention"
        advice = (
            "Monitor your symptoms more closely, reduce salt intake, maintain stress-free activities, "
            "and follow up with your doctor within the next few days."
        )
    else:
        result_text = "high and may indicate a developing complication"
        advice = (
            "Immediate medical evaluation is recommended. Ensure strict adherence to prescribed medication, "
            "avoid physical strain, and seek emergency care if symptoms worsen."
        )

    # Doctor-style recommendation output
    recommendation = f"""
Doctor's Recommendation:
---------------------------------------
Based on the patient's profile:

• Age: {age}
• Medical Condition: {condition}
• Current Medication: {medication}
• Predicted Test Result: The patient's values appear to be {result_text}.

Medical Advice:
{advice}

Please consult a certified physician for a full clinical evaluation.
"""
    return recommendation

# Generate and display output
print(generate_ai_doctor_recommendation(sample_patient))
